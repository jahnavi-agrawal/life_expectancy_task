# %% [markdown]
# # **Exploration Data Analysis:**
# **Import packages:**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
sns.set(style="whitegrid")

# %% [markdown]
# **Load Dataset:**

# %%
data_path = "E:\Visual Studio Code\IML\Jahnavi_Neha_A1\life_expectancy_task\data\Life Expectancy Raw.csv"
data = pd.read_csv(data_path)
print("Loaded Raw Dataset:", data_path)
# Out:
# Loaded Raw Dataset: E:\Visual Studio Code\IML\Jahnavi_Neha_A1\life_expectancy_task\data\Life Expectancy Raw.csv

# %% [markdown]
# **Data Preview:**

# %%
data.head(5)
# Out:
#        Country  Year      Status  Life expectancy  Adult Mortality  \
# 0      Hungary  2009   Developed             74.2            162.0
# 1    Singapore  2010   Developed             82.0             61.0
# 2  New Zealand  2008   Developed             81.0             75.0
# 3     Honduras  2000  Developing             71.0            174.0
# 4        Egypt  2002  Developing             68.7            177.0
#
#    infant deaths  Alcohol  percentage expenditure  Hepatitis B  Measles  ...  \
# 0              0    11.46             1281.155944          NaN        1  ...
# 1              0     1.84             4540.543752         96.0       50  ...
# 2              0     9.49             6761.288966          9.0        0  ...
# 3              6     2.61               28.808311         93.0        0  ...
# 4             61     0.15                0.000000         97.0      653  ...
#
#    Polio  Total expenditure  Diphtheria  HIV/AIDS           GDP  Population  \
# 0   99.0               7.55        99.0       0.1  12967.165430     12265.0
# 1   96.0               3.96        96.0       0.1  46569.679510         NaN
# 2   89.0               1.70        89.0       0.1  31287.778650         NaN
# 3   88.0               6.63        94.0       1.7    188.783165   6524283.0
# 4   97.0               5.97        97.0       0.1           NaN         NaN
#
#    thinness  1-19 years  thinness 5-9 years  Income composition of resources  \
# 0                   1.8                 1.8                            0.816
# 1                   2.1                 2.1                            0.889
# 2                   0.3                 0.3                            0.894
# 3                   2.8                 2.7                            0.551
# 4                   3.4                 3.4                            0.617
#
#    Schooling
# 0       15.3
# 1       14.5
# 2       19.5
# 3        9.8
# 4       11.2
#
# [5 rows x 22 columns]

# %% [markdown]
# **Data Summary:**

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2497 entries, 0 to 2496
# Data columns (total 22 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   Country                          2497 non-null   object
#  1   Year                             2497 non-null   int64
#  2   Status                           2497 non-null   object
#  3   Life expectancy                  2488 non-null   float64
#  4   Adult Mortality                  2488 non-null   float64
#  5   infant deaths                    2497 non-null   int64
#  6   Alcohol                          2333 non-null   float64
#  7   percentage expenditure           2497 non-null   float64
#  8   Hepatitis B                      2016 non-null   float64
#  9   Measles                          2497 non-null   int64
#  10  BMI                              2466 non-null   float64
#  11  under-five deaths                2497 non-null   int64
#  12  Polio                            2481 non-null   float64
#  13  Total expenditure                2306 non-null   float64
#  14  Diphtheria                       2481 non-null   float64
#  15  HIV/AIDS                         2497 non-null   float64
#  16  GDP                              2132 non-null   float64
#  17  Population                       1957 non-null   float64
#  18  thinness  1-19 years             2466 non-null   float64
#  19  thinness 5-9 years               2466 non-null   float64
#  20  Income composition of resources  2356 non-null   float64
#  21  Schooling                        2360 non-null   float64
# dtypes: float64(16), int64(4), object(2)
# memory usage: 429.3+ KB

# %%
data.describe()
# Out:
#               Year  Life expectancy  Adult Mortality  infant deaths  \
# count  2497.000000      2488.000000      2488.000000    2497.000000
# mean   2007.479375        69.143770       164.647508      28.987185
# std       4.616338         9.517112       124.080010     107.624711
# min    2000.000000        36.300000         1.000000       0.000000
# 25%    2003.000000        63.200000        74.000000       0.000000
# 50%    2007.000000        72.000000       144.000000       3.000000
# 75%    2011.000000        75.525000       227.000000      22.000000
# max    2015.000000        89.000000       723.000000    1800.000000
#
#            Alcohol  percentage expenditure  Hepatitis B        Measles  \
# count  2333.000000             2497.000000  2016.000000    2497.000000
# mean      4.577008              731.548870    81.008433    2431.130156
# std       4.056307             1987.075471    25.107816   11740.711517
# min       0.010000                0.000000     1.000000       0.000000
# 25%       0.850000                5.347718    77.000000       0.000000
# 50%       3.670000               64.398533    92.000000      17.000000
# 75%       7.680000              437.105966    96.000000     383.000000
# max      17.870000            19479.911610    99.000000  212183.000000
#
#                BMI  under-five deaths        Polio  Total expenditure  \
# count  2466.000000        2497.000000  2481.000000        2306.000000
# mean     38.092863          40.258710    82.419589           5.936544
# std      20.098019         147.252113    23.703581           2.493682
# min       1.400000           0.000000     3.000000           0.370000
# 25%      19.100000           0.000000    78.000000           4.252500
# 50%      43.000000           4.000000    93.000000           5.750000
# 75%      56.100000          28.000000    97.000000           7.530000
# max      87.300000        2500.000000    99.000000          17.600000
#
#         Diphtheria     HIV/AIDS            GDP    Population  \
# count  2481.000000  2497.000000    2132.000000  1.957000e+03
# mean     82.240226     1.699199    7348.579392  1.313189e+07
# std      23.914151     4.898429   14143.733665  6.507472e+07
# min       2.000000     0.100000       3.685949  3.400000e+01
# 25%      78.000000     0.100000     458.064238  1.822860e+05
# 50%      93.000000     0.100000    1683.750332  1.354493e+06
# 75%      97.000000     0.800000    5858.119655  7.472819e+06
# max      99.000000    50.600000  119172.741800  1.293859e+09
#
#        thinness  1-19 years  thinness 5-9 years  \
# count           2466.000000         2466.000000
# mean               4.818613            4.863058
# std                4.375821            4.484728
# min                0.100000            0.100000
# 25%                1.600000            1.525000
# 50%                3.300000            3.300000
# 75%                7.200000            7.200000
# max               27.700000           28.600000
#
#        Income composition of resources    Schooling
# count                      2356.000000  2360.000000
# mean                          0.625069    11.959534
# std                           0.213123     3.380734
# min                           0.000000     0.000000
# 25%                           0.489750    10.100000
# 50%                           0.676500    12.300000
# 75%                           0.780000    14.200000
# max                           0.948000    20.700000

# %%
# Out:
# Status
# Developed     79.131808
# Developing    67.015651
# Name: Life expectancy, dtype: float64

# %% [markdown]
# **Handling Missing Values:**

# %%
data.isnull().sum().sort_values(ascending=False)
# Out:
# Population                         540
# Hepatitis B                        481
# GDP                                365
# Total expenditure                  191
# Alcohol                            164
# Income composition of resources    141
# Schooling                          137
# thinness  1-19 years                31
# thinness 5-9 years                  31
# BMI                                 31
# Diphtheria                          16
# Polio                               16
# Life expectancy                      9
# Adult Mortality                      9
# infant deaths                        0
# Status                               0
# Country                              0
# Year                                 0
# under-five deaths                    0
# Measles                              0
# percentage expenditure               0
# HIV/AIDS                             0
# dtype: int64

# %% [markdown]
# **Dropping Target variable:**

# %%
target= data["Life expectancy"]
#data= data.drop(columns=["Country", "Year", "Measles"])
#removed measles because it was an absolute value
data.shape
# Out:
# (2497, 22)

# %% [markdown]
# **Filling Missing Value:**

# %%
# Replacing missing values with mean
# num= numerical columns
num = data.select_dtypes(include=[np.number]).columns
for col in num:
    data[col].fillna(data[col].mean())

# %%
# Filling categorical features with mode
# cat= categorical columns 
cat = data.select_dtypes(include=['object']).columns
for col in cat:
    data[col].fillna(data[col].mode()[0])

# %% [markdown]
# **Verifying Missing Values**

# %%
print(data.isnull().sum())
# Out:
# Country                              0
# Year                                 0
# Status                               0
# Life expectancy                      9
# Adult Mortality                      9
# infant deaths                        0
# Alcohol                            164
# percentage expenditure               0
# Hepatitis B                        481
# Measles                              0
# BMI                                 31
# under-five deaths                    0
# Polio                               16
# Total expenditure                  191
# Diphtheria                          16
# HIV/AIDS                             0
# GDP                                365
# Population                         540
# thinness  1-19 years                31
# thinness 5-9 years                  31
# Income composition of resources    141
# Schooling                          137
# dtype: int64

# %% [markdown]
# **Metrics:**

# %%
print(data.groupby("Status")["Life expectancy"].mean())
# Out:
# Status
# Developed     79.131808
# Developing    67.015651
# Name: Life expectancy, dtype: float64

# %% [markdown]
# It is obvious, a developed country would have proper resources and awareness that can ensure a better life expectancy. Also the trend chart below will show how average life expectancy has improved over the years.

# %%
avg_by_year = data.groupby("Year")["Life expectancy"].mean()
sns.lineplot(x=avg_by_year.index, y=avg_by_year.values)
plt.title("Average Life Expectancy Over Time")
plt.show()

# %%
corr = data.select_dtypes(include=['number']).corr()
life_corr = corr["Life expectancy"].drop("Life expectancy")
life_corr_sorted = life_corr.sort_values(ascending=False). round(3)

print("Correlation of features with Life Expectancy:")
print(life_corr_sorted)
# Out:
# Correlation of features with Life Expectancy:
# Schooling                          0.756
# Income composition of resources    0.726
# BMI                                0.563
# Diphtheria                         0.485
# Polio                              0.468
# GDP                                0.462
# Alcohol                            0.402
# percentage expenditure             0.382
# Hepatitis B                        0.256
# Total expenditure                  0.223
# Year                               0.169
# Population                        -0.021
# Measles                           -0.161
# infant deaths                     -0.208
# under-five deaths                 -0.235
# thinness 5-9 years                -0.471
# thinness  1-19 years              -0.477
# HIV/AIDS                          -0.559
# Adult Mortality                   -0.690
# Name: Life expectancy, dtype: float64

# %% [markdown]
# On paying attention to the "Life expectancy" row, we find that there is negative correlation with constructs like Adult Mortality, HIV, malnutrition etc and positive correlation with Schooling, Income composition, BMI etc.

# %%
plt.figure(figsize=(10,6))
life_corr_sorted.plot(kind='bar', color=['skyblue' if v > 0 else 'salmon' for v in life_corr_sorted])
plt.title("Correlation of Features with Life Expectancy", fontsize=14)
plt.ylabel("Correlation Coefficient", fontsize=12)
plt.xticks(rotation=75, ha="right")
plt.grid(axis="y", linestyle="--", alpha=0.7)
plt.show()

# %%
cols = ["Adult Mortality", "Schooling", "HIV/AIDS", "Income composition of resources", "Total expenditure", "Alcohol"]
fig, axes = plt.subplots(3, 2, figsize=(12, 10))

for i, col in enumerate(cols):
    row, col_pos = divmod(i, 2)  # find row and column index
    sns.scatterplot(x=data[col], y=data["Life expectancy"], ax=axes[row, col_pos], color= "teal")
    axes[row, col_pos].set_title(f"Life Expectancy vs {col}")

plt.tight_layout()
plt.show()

# %%
selected=["Adult Mortality", "Schooling", "HIV/AIDS", "Income composition of resources", "BMI"]

data[selected].hist(figsize=(12,8), bins=30, edgecolor="black")
plt.tight_layout()
plt.show()

# %% [markdown]
# # Insights:

# %% [markdown]
# a) Education (Schooling, 0.76) and income equality (0.73) are the strongest positive drivers of life expectancy.
#
# b) Higher vaccination rates (Diphtheria, Polio, Hepatitis B) and healthcare spending also improve life expectancy.
#
# c) Adult Mortality (-0.69), HIV/AIDS (-0.56), and child malnutrition (thinness, -0.47) are the strongest negative factors.
#
# d) GDP matters (0.46), but social and health factors (education, disease prevention) play a larger role.
